# %%
import numpy as np
data= np.array([
    [10,1000],
    [20,2000],
    [30,3000]
])
print(data.ndim)
print(data.dtype)
print(data.shape)
print(data.size)
# Out:
# 2
# int64
# (3, 2)
# 6

# %%
import numpy as np
number= np.array([1,2,3,4,5])
results=number*10
print(results)
# Out:
# [10 20 30 40 50]
