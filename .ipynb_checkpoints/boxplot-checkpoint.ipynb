# %%
import matplotlib.pyplot as plt
import pandas as pd
bp = pd.DataFrame({
    "Employee_Name": ["Ramesh","Amesh","Mesh","Esh","Sh","H","Anish","Nish"], 
    "Salary" : [1000,2000,3000,4000,5000,6000,7000,8000]
})
bp
# Out:
#   Employee_Name  Salary
# 0        Ramesh    1000
# 1         Amesh    2000
# 2          Mesh    3000
# 3           Esh    4000
# 4            Sh    5000
# 5             H    6000
# 6         Anish    7000
# 7          Nish    8000

# %%
plt.boxplot(bp["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x121a82d17f0>,
#   <matplotlib.lines.Line2D at 0x121a82d1940>],
#  'caps': [<matplotlib.lines.Line2D at 0x121a82d1a90>,
#   <matplotlib.lines.Line2D at 0x121a82d1be0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x121a82d16a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x121a82d1d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x121a82d1e80>],
#  'means': []}

# %%
bp3= pd.read_csv("datasets/daraz_dataset.csv")
plt.boxplot(bp3["TotalAmount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x121aa4a2a50>,
#   <matplotlib.lines.Line2D at 0x121aa4a2ba0>],
#  'caps': [<matplotlib.lines.Line2D at 0x121aa4a2cf0>,
#   <matplotlib.lines.Line2D at 0x121aa4a2e40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x121aa4a2900>],
#  'medians': [<matplotlib.lines.Line2D at 0x121aa4a2f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x121aa4a30e0>],
#  'means': []}
