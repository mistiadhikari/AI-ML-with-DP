# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

index= [1,2,3,4]
price=[1000,2000,3000,4300]
plt.plot(index,price)
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import pandas as pd
dd= pd.read_csv("datasets/daraz_dataset.csv")
category= dd.groupby("Category")["Product"].count()
category
# Out:
# Category
# Beauty         58
# Books          78
# Electronics    73
# Fashion        64
# Groceries      75
# Home           81
# Sports         71
# Name: Product, dtype: int64

# %%
plt.bar(category.index, category.values,color="pink", edgecolor= "black")
plt.xlabel("Categories",fontsize=20)
plt.ylabel("Products",fontsize=20)
plt.title("products and category bargraph")
plt.grid(axis= "y",linestyle= "--",alpha=1)
